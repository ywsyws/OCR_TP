# %%
import numpy as np
from PIL import Image

# %%
img = Image.open('simba.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=250x263 at 0x7F1B7C357B38>

# %%
# Récupérer et afficher la taille de l'image (en pixels)
w, h = img.size
print("Largeur : {} px, hauteur : {} px".format(w, h))
# Out:
# Largeur : 250 px, hauteur : 263 px

# %%
img.size
# Out:
# (250, 263)

# %%
img.mode
# Out:
# 'L'

# %%
img.getpixel((20,100))
# Out:
# 196

# %%
mat = np.array(img)
mat
# Out:
# array([[247, 245, 245, ..., 224, 228, 228],
#        [246, 244, 243, ..., 228, 230, 230],
#        [244, 242, 240, ..., 230, 231, 231],
#        ...,
#        [183, 169, 169, ..., 108,  95, 102],
#        [170, 160, 171, ...,  81,  95,  99],
#        [150, 155, 174, ..., 133, 115, 111]], dtype=uint8)

# %%
print(mat.shape)
print(mat.T.shape)
# Out:
# (263, 250)
# (250, 263)
